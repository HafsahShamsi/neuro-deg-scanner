# %% [markdown]
# # neuro-deg-scanner — Example: Systemic Lupus Erythematosus
#
# Same pipeline, different disease. Swap the GEO ID and keywords — that's it.

# %%
import sys
sys.path.insert(0, '..')

from neuro_deg_scanner import run

results = run(
    geo_id           = 'GSE50772',   # SLE whole blood dataset
    disease_label    = 'SLE',
    disease_keywords = ['sle', 'lupus', 'patient'],
    healthy_keywords = ['healthy', 'control', 'normal'],
    fdr_threshold    = 0.05,
    lfc_threshold    = 0.5,
    output_dir       = '../outputs/GSE50772_SLE',
)
# Out:
# ...
#   neuro-deg-scanner  ·  GSE50772  ·  SLE
# ...
#
# [1/5] Fetching GSE50772 from NCBI GEO...
#       Title   : Expression data in PBMCs from SLE patients and controls
#       Samples : 81
# [2/5] Building expression matrix...
#       Matrix  : 19,943 probes × 81 samples
#       Labels  : 61 disease / 20 healthy / 0 unknown
# [2/5] Normalising and filtering...
#       log2(x+1) applied  (median was 247.0)
#       Probes  : 19,943 → 4,986 (top 25% by variance)
# [3/5] Running differential expression...
#       Upregulated   :   396
#       Downregulated :   531
#       Not sig.      : 4,059
# [4/5] Generating plots...
#       Saved  → ../outputs/GSE50772_SLE\pca.png
#       Saved  → ../outputs/GSE50772_SLE\volcano.png
#       Saved  → ../outputs/GSE50772_SLE\heatmap.png
# [5/5] Generating report...
#
# ...
#   NEURO-DEG-SCANNER  ·  RESULTS SUMMARY
# ...
#   Dataset         : GSE50772
#   Condition       : SLE vs Healthy
#   Disease samples : 61
#   Healthy samples : 20
#   Probes tested   : 4,986
# ...
